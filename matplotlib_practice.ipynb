# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import statistics
import numpy as np
from matplotlib.ticker import MultipleLocator
import pandas as pd

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
ax = plt.axes()
ax.plot(x_axis, y_axis)

#plt.plot(x_axis,y_axis)
#plt.show()

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston',marker="*",color="blue",linewidth=2)
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")

#plt.xlim("Jan", "June")
plt.xlim(0, 5)

plt.figure(figsize=(20, 10))
# Add the legend.
plt.show()

# %%
ax = plt.subplot()
ax.plot(x_axis, y_axis, label='Boston',marker="*",color="blue",linewidth=2)
ax.set_xlim("Jan","June")
# Out:
# (0.0, 5.0)

# %%
plt.subplots(figsize=(20, 10))
# Out:
# (<Figure size 1440x720 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1a354bb8af0>)

# %%
# Create the plot and add a label for the legend.
plt.plot(x_axis, y_axis, label='Boston',marker="D",color="green",linewidth=2,)
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")

plt.xlim("Jan", "Dec")
#plt.xlim(0, 5)
plt.ylim(0,45)
plt.grid()

plt.figure(figsize=(20, 10))
# Add the legend.
plt.show()

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(x_axis, y_axis, label='Boston',marker="D",color="green",linewidth=2)

# Create labels for the x and y axes.
ax.set_xlabel("Date")
ax.set_ylabel("Fare($)")
# Set the y limit between 0 and 45.
ax.set_ylim(0, 45)
# Create a title.
ax.set_title("PyBer Fare by Month")

ax.set_xlim("Jan", "Dec")
#plt.xlim(0, 5)
ax.set_ylim(0,45)
ax.grid()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot.
plt.bar(x_axis, y_axis, color="green", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()

# %%
# Create the plot
plt.barh(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(y_axis, x_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis)
plt.gca().invert_yaxis()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()
plt.gca().invert_yaxis()
plt.show()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]
plt.subplots(figsize=(8, 8))
#plt.plot(x_axis, y_axis,'o',c='r')
plt.plot(y_axis, x_axis,'o',color='r',label="Chicago")
plt.gca().invert_yaxis()
plt.xlabel("Fare ($)")
plt.ylabel("Date")
plt.title("PyBer Fare by Month")
plt.legend()
plt.show()

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data * 3)
    
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()

# %%
explode_values = (0, 0, 0, 0, 0, 0, 0, 0.3, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
plt.pie(y_axis,  labels=x_axis, autopct='%.1f%%',explode=explode_values,colors = colors  )
plt.show()

# %%
stdev = statistics.stdev(y_axis)
stdev


plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(x_axis, y_axis, yerr=stdev, capsize=3)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0,51, step =5))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-121-cced9c112d4c> in <module>
#       1 plt.barh(x_axis, y_axis)
#       2 plt.xticks(np.arange(0,51, step =5))
# ----> 3 plt.xticks.set_minor_locator(MultipleLocator(1))
#       4 plt.show()
#
# AttributeError: 'function' object has no attribute 'set_minor_locator'

# %%
# Load in csv
pyber_ride_df = pd.read_csv("Resources/PyBer_ride_data.csv")

pyber_ride_df.plot(x="Month",y="Avg. Fare ($USD)")

x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]
#print(tick_locations)

plt.xticks(tick_locations,pyber_ride_df["Month"])

plt.show()

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar')
plt.show()

# %%
pyber_ride_df.plot(x="Month", y="Avg. Fare ($USD)", kind='bar',color = 'skyblue')

#plt.errorbar(x_axis, y_axis, yerr=stdev, capsize=3)
plt.yticks(np.arange(0,51, step =5))
stdev = statistics.stdev(y_axis)


plt.errorbar(pyber_ride_df["Month"], pyber_ride_df["Avg. Fare ($USD)"], yerr=stdev, capsize=3,color = 'black')
plt.show()
